# %%
import numpy as np
import pandas as pd

# %%
l=[]
li=[3,3,3,3,3,1,1,3,3,3
,1,3,1,7,7,7,7,1,3,3
,1,4,2,3,7,3,1,3,1,3
,4,4,3,1,3,3,4,1,1,3
,3,1,3,1,7,1,3,4,3,1
,1,1,3,5,5,5,5,5,5,5
,5,2,1,3,1,1,1,4,1,7
,2,4,2,3,3,4,2,7,7,1
,1,3,3,1,4,2,3,1,1,1
,4,3,1,1,3,4,3,1,2,3
,2,4,2]
bum=[2,3,2,3,3,1,1,2,3,3
,1,3,1,5,6,6,5,4,3,2
,6,1,3,3,2,2,1,2,4,3
,1,1,3,1,3,3,4,1,4,2
,2,1,2,4,6,4,3,4,3,1
,1,4,2,6,6,6,6,6,6,6
,6,2,4,2,1,1,1,4,1,6
,2,4,2,3,2,4,2,5,5,4
,1,3,3,1,1,3,3,1,1,1
,1,3,1,4,2,4,3,4,3,2
,2,4,2]
bem=[3,2,2,2,2,1,1,2,3,3
,1,3,1,6,6,5,6,'N',3,2
,6,1,3,3,1,2,1,2,4,'N'
,1,4,3,1,3,3,4,1,4,2
,3,1,2,4,5,4,3,4,4,1
,4,4,2,6,6,6,6,6,6,6
,6,2,4,2,4,1,1,4,1,5
,2,4,2,3,2,4,2,5,5,4
,1,3,3,1,1,3,3,1,1,1
,1,3,1,4,2,4,3,4,3,2
,2,4,2]

# %%
for i in li:
    if i ==1:
        l.append("Bullish Reversal")
    elif i==2:
        l.append("Bullish Continuation")
    elif i==3:
        l.append("Bearish Reversal")
    elif i==4:
        l.append("Bearish Continuation")
    elif i==5:
        l.append("Reversal")
    elif i==6:
        l.append("Continuation")
    else:
        l.append("Indecision")

# %%
l
# Out:
# ['Bearish Reversal',
#  'Bearish Reversal',
#  'Bearish Reversal',
#  'Bearish Reversal',
#  'Bearish Reversal',
#  'Bullish Reversal',
#  'Bullish Reversal',
#  'Bearish Reversal',
#  'Bearish Reversal',
#  'Bearish Reversal',
#  'Bullish Reversal',
#  'Bearish Reversal',
#  'Bullish Reversal',
#  'Indecision',
#  'Indecision',
#  'Indecision',
#  'Indecision',
#  'Bullish Reversal',
#  'Bearish Reversal',
#  'Bearish Reversal',
#  'Bullish Reversal',
#  'Bearish Continuation',
#  'Bullish Continuation',
#  'Bearish Reversal',
#  'Indecision',
#  'Bearish Reversal',
#  'Bullish Reversal',
#  'Bearish Reversal',
#  'Bullish Reversal',
#  'Bearish Reversal',
#  'Bearish Continuation',
#  'Bearish Continuation',
#  'Bearish Reversal',
#  'Bullish Reversal',
#  'Bearish Reversal',
#  'Bearish Reversal',
#  'Bearish Continuation',
#  'Bullish Reversal',
#  'Bullish Reversal',
#  'Bearish Reversal',
#  'Bearish Reversal',
#  'Bullish Reversal',
#  'Bearish Reversal',
# ...

# %%
al=pd.concat([theo,bull,bear],axis=1)
al
# Out:
#                         0                     1                     2
# 0        Bearish Reversal  Bullish Continuation      Bearish Reversal
# 1        Bearish Reversal      Bearish Reversal  Bullish Continuation
# 2        Bearish Reversal  Bullish Continuation  Bullish Continuation
# 3        Bearish Reversal      Bearish Reversal  Bullish Continuation
# 4        Bearish Reversal      Bearish Reversal  Bullish Continuation
# ..                    ...                   ...                   ...
# 98   Bullish Continuation      Bearish Reversal      Bearish Reversal
# 99       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 100  Bullish Continuation  Bullish Continuation  Bullish Continuation
# 101  Bearish Continuation  Bearish Continuation  Bearish Continuation
# 102  Bullish Continuation  Bullish Continuation  Bullish Continuation
#
# [103 rows x 3 columns]

# %%
peb=[50,54,61,74,52
,55,67,61,65,69
,71,89,71,53,53
,51,50,'N',63,75
,51,54,58,51,50
,52,51,67,71,'N'
,59,51,82,62,30
,72,67,59,67,59
,50,51,56,56,52
,57,72,65,80,50
,51,67,67,56,53
,54,54,55,53,54
,56,67,61,53,52
,71,65,58,60,50
,79,76,69,60,58
,57,64,52,52,63
,61,79,63,63,77
,83,70,74,100,84
,57,61,55,56,55
,69,58,57,72,53
,53,73,72]
be=[]
for i in peb:
    i=str(i)+"%"
    be.append(i)
be
# Out:
# ['50%',
#  '54%',
#  '61%',
#  '74%',
#  '52%',
#  '55%',
#  '67%',
#  '61%',
#  '65%',
#  '69%',
#  '71%',
#  '89%',
#  '71%',
#  '53%',
#  '53%',
#  '51%',
#  '50%',
#  'N%',
#  '63%',
#  '75%',
#  '51%',
#  '54%',
#  '58%',
#  '51%',
#  '50%',
#  '52%',
#  '51%',
#  '67%',
#  '71%',
#  'N%',
#  '59%',
#  '51%',
#  '82%',
#  '62%',
#  '30%',
#  '72%',
#  '67%',
#  '59%',
#  '67%',
#  '59%',
#  '50%',
#  '51%',
#  '56%',
#  '56%',
#  '52%',
#  '57%',
#  '72%',
#  '65%',
#  '80%',
#  '50%',
#  '51%',
#  '67%',
#  '67%',
#  '56%',
#  '53%',
#  '54%',
#  '54%',
#  '55%',
#  '53%',
#  '54%',
#  '56%',
#  '67%',
#  '61%',
#  '53%',
#  '52%',
#  '71%',
#  '65%',
#  '58%',
#  '60%',
#  '50%',
#  '79%',
#  '76%',
#  '69%',
#  '60%',
#  '58%',
#  '57%',
#  '64%',
#  '52%',
#  '52%',
#  '63%',
#  '61%',
#  '79%',
#  '63%',
#  '63%',
#  '77%',
#  '83%',
#  '70%',
#  '74%',
#  '100%',
#  '84%',
#  '57%',
#  '61%',
#  '55%',
#  '56%',
#  '55%',
#  '69%',
#  '58%',
#  '57%',
#  '72%',
#  '53%',
# ...

# %%
pub=pd.Series(bu)
pub
# Out:
# 0     62%
# 1     54%
# 2     79%
# 3     63%
# 4     71%
#      ...
# 68    59%
# 69    60%
# 70    57%
# 71    67%
# 72    75%
# Length: 73, dtype: object

# %%
pub=[53,51,51,57,69
,70,66,64,60,68
,71,63,59,52,52
,52,51,75,60,77
,50,56,57,51,51
,51,52,69,64,63
,62,54,79,63,71
,72,71,60,65,59
,53,53,57,55,51
,56,79,53,54,53
,56,65,68,53,58
,53,52,53,52,54
,56,78,61,51,56
,76,78,56,64,51
,74,63,72,59,61
,56,66,51,50,62
,66,78,60,65,84
,65,69,75,86,82
,57,52,60,52,56
,68,54,60,59,60
,57,67,75]
bu=[]
for i in pub:
    i=str(i)+"%"
    bu.append(i)
bu
# Out:
# ['53%',
#  '51%',
#  '51%',
#  '57%',
#  '69%',
#  '70%',
#  '66%',
#  '64%',
#  '60%',
#  '68%',
#  '71%',
#  '63%',
#  '59%',
#  '52%',
#  '52%',
#  '52%',
#  '51%',
#  '75%',
#  '60%',
#  '77%',
#  '50%',
#  '56%',
#  '57%',
#  '51%',
#  '51%',
#  '51%',
#  '52%',
#  '69%',
#  '64%',
#  '63%',
#  '62%',
#  '54%',
#  '79%',
#  '63%',
#  '71%',
#  '72%',
#  '71%',
#  '60%',
#  '65%',
#  '59%',
#  '53%',
#  '53%',
#  '57%',
#  '55%',
#  '51%',
#  '56%',
#  '79%',
#  '53%',
#  '54%',
#  '53%',
#  '56%',
#  '65%',
#  '68%',
#  '53%',
#  '58%',
#  '53%',
#  '52%',
#  '53%',
#  '52%',
#  '54%',
#  '56%',
#  '78%',
#  '61%',
#  '51%',
#  '56%',
#  '76%',
#  '78%',
#  '56%',
#  '64%',
#  '51%',
#  '74%',
#  '63%',
#  '72%',
#  '59%',
#  '61%',
#  '56%',
#  '66%',
#  '51%',
#  '50%',
#  '62%',
#  '66%',
#  '78%',
#  '60%',
#  '65%',
#  '84%',
#  '65%',
#  '69%',
#  '75%',
#  '86%',
#  '82%',
#  '57%',
#  '52%',
#  '60%',
#  '52%',
#  '56%',
#  '68%',
#  '54%',
#  '60%',
#  '59%',
#  '60%',
# ...

# %%
peb=pd.Series(be)
pub=pd.Series(bu)
al=pd.concat([peb,pub,al],axis=1)

# %%
al

# %%
al
# Out:
#        0    1                     0                     1  \
# 0    50%  53%      Bearish Reversal  Bullish Continuation
# 1    54%  51%      Bearish Reversal      Bearish Reversal
# 2    61%  51%      Bearish Reversal  Bullish Continuation
# 3    74%  57%      Bearish Reversal      Bearish Reversal
# 4    52%  69%      Bearish Reversal      Bearish Reversal
# ..   ...  ...                   ...                   ...
# 98   72%  59%  Bullish Continuation      Bearish Reversal
# 99   53%  60%      Bearish Reversal  Bullish Continuation
# 100  53%  57%  Bullish Continuation  Bullish Continuation
# 101  73%  67%  Bearish Continuation  Bearish Continuation
# 102  72%  75%  Bullish Continuation  Bullish Continuation
#
#                         2
# 0        Bearish Reversal
# 1    Bullish Continuation
# 2    Bullish Continuation
# 3    Bullish Continuation
# 4    Bullish Continuation
# ..                    ...
# 98       Bearish Reversal
# 99   Bullish Continuation
# ...

# %%
bu=[37,50,46,36,14
,13,17,15,27,16
,11,23,31,41,47
,45,46,'N',24,4
,50,37,34,52,49
,48,48,8,16,24
,25,42,5,22,12
,10,7,26,13,23
,36,43,25,32,51
,31,4,19,41,44
,39,14,9,38,24
,35,43,33,42,34
,30,1,19,44,38
,8,6,29,21,47
,5,17,6,33,20
,27,12,49,53,18
,18,7,29,20,2
,19,15,9,1,3
,35,46,30,40,28
,10,40,22,32,21
,26,11,4]
be=[44,40,22,5,48
,34,18,20,20,17
,14,2,12,45,44
,42,53,'N',24,4
,50,36,58,51,50
,49,40,11,8,'N'
,30,52,5,25,15
,11,15,29,13,23
,46,41,33,32,39
,26,10,17,1,48
,51,12,14,31,35
,39,37,36,43,38
,29,16,21,46,47
,13,19,25,28,45
,2,3,10,27,24
,27,18,38,37,19
,21,6,22,23,7
,4,16,8,1,3
,33,26,35,30,34
,9,31,28,9,41
,42,6,7]
bu=pd.Series(bu)
be=pd.Series(be)

# %%
bu
# Out:
# 0      37
# 1      50
# 2      46
# 3      36
# 4      14
#        ..
# 98     32
# 99     21
# 100    26
# 101    11
# 102     4
# Length: 103, dtype: object

# %%
al
# Out:
#        0    1                     0                     1  \
# 0    50%  53%      Bearish Reversal  Bullish Continuation
# 1    54%  51%      Bearish Reversal      Bearish Reversal
# 2    61%  51%      Bearish Reversal  Bullish Continuation
# 3    74%  57%      Bearish Reversal      Bearish Reversal
# 4    52%  69%      Bearish Reversal      Bearish Reversal
# ..   ...  ...                   ...                   ...
# 98   72%  59%  Bullish Continuation      Bearish Reversal
# 99   53%  60%      Bearish Reversal  Bullish Continuation
# 100  53%  57%  Bullish Continuation  Bullish Continuation
# 101  73%  67%  Bearish Continuation  Bearish Continuation
# 102  72%  75%  Bullish Continuation  Bullish Continuation
#
#                         2
# 0        Bearish Reversal
# 1    Bullish Continuation
# 2    Bullish Continuation
# 3    Bullish Continuation
# 4    Bullish Continuation
# ..                    ...
# 98       Bearish Reversal
# 99   Bullish Continuation
# ...

# %%
al=pd.concat([bu,be,al],axis=1)

# %%
al
# Out:
#       0   1    0    1                     0                     1  \
# 0    37  44  50%  53%      Bearish Reversal  Bullish Continuation
# 1    50  40  54%  51%      Bearish Reversal      Bearish Reversal
# 2    46  22  61%  51%      Bearish Reversal  Bullish Continuation
# 3    36   5  74%  57%      Bearish Reversal      Bearish Reversal
# 4    14  48  52%  69%      Bearish Reversal      Bearish Reversal
# ..   ..  ..  ...  ...                   ...                   ...
# 98   32   9  72%  59%  Bullish Continuation      Bearish Reversal
# 99   21  41  53%  60%      Bearish Reversal  Bullish Continuation
# 100  26  42  53%  57%  Bullish Continuation  Bullish Continuation
# 101  11   6  73%  67%  Bearish Continuation  Bearish Continuation
# 102   4   7  72%  75%  Bullish Continuation  Bullish Continuation
#
#                         2
# 0        Bearish Reversal
# 1    Bullish Continuation
# 2    Bullish Continuation
# 3    Bullish Continuation
# 4    Bullish Continuation
# ...

# %%
freq=[52,69,87,90,96
,92,32,65,38,19
,22,98,97,3,50
,54,4,103,46,48
,44,57,49,42,41
,6,8,43,53,101
,84,68,11,12,81
,71,91,36,61,16
,26,25,45,47,17
,34,83,62,102,100
,80,13,14,9,10
,30,18,15,5,7
,27,93,58,63,72
,78,66,70,40,55
,88,82,76,37,51
,86,73,1,2,59
,28,60,33,31,94
,95,21,24,99,67
,56,77,79,39,35
,29,64,89,85,75
,74,23,20]

opt=[90,100,99,95,64
,9,31,54,59,63
,62,11,45,82,66
,85,68,101,22,93
,98,88,92,77,37
,83,78,51,49,97
,26,23,91,84,30
,4,89,65,6,87
,72,38,80,50,67
,21,24,17,102,96
,41,48,79,19,53
,57,43,70,58,75
,71,86,8,16,18
,25,12,33,13,35
,94,40,36,55,52
,29,46,73,69,14
,47,3,56,20,1
,2,39,34,103,32
,15,76,28,44,81
,10,61,60,27,74
,5,7,42]
peb=pd.Series(freq)
pub=pd.Series(opt)
al=pd.concat([peb,pub,al],axis=1)
al
# Out:
#       0    1   0   1    0    1                     0                     1  \
# 0    52   90  37  44  50%  53%      Bearish Reversal  Bullish Continuation
# 1    69  100  50  40  54%  51%      Bearish Reversal      Bearish Reversal
# 2    87   99  46  22  61%  51%      Bearish Reversal  Bullish Continuation
# 3    90   95  36   5  74%  57%      Bearish Reversal      Bearish Reversal
# 4    96   64  14  48  52%  69%      Bearish Reversal      Bearish Reversal
# ..   ..  ...  ..  ..  ...  ...                   ...                   ...
# 98   85   27  32   9  72%  59%  Bullish Continuation      Bearish Reversal
# 99   75   74  21  41  53%  60%      Bearish Reversal  Bullish Continuation
# 100  74    5  26  42  53%  57%  Bullish Continuation  Bullish Continuation
# 101  23    7  11   6  73%  67%  Bearish Continuation  Bearish Continuation
# 102  20   42   4   7  72%  75%  Bullish Continuation  Bullish Continuation
#
#                         2
# 0        Bearish Reversal
# ...

# %%
al.to_csv("output.csv")

# %%
import pandas as pd
a=pd.read_csv("output.csv")
a
# Out:
#      Unnamed: 0           Theoretical             Act Bull   \
# 0             0      Bearish Reversal  Bullish Continuation
# 1             1      Bearish Reversal      Bearish Reversal
# 2             2      Bearish Reversal  Bullish Continuation
# 3             3      Bearish Reversal      Bearish Reversal
# 4             4      Bearish Reversal      Bearish Reversal
# ..          ...                   ...                   ...
# 98           98  Bullish Continuation      Bearish Reversal
# 99           99      Bearish Reversal  Bullish Continuation
# 100         100  Bullish Continuation  Bullish Continuation
# 101         101  Bearish Continuation  Bearish Continuation
# 102         102  Bullish Continuation  Bullish Continuation
#
#                  Act Bear  Unnamed: 4  Bull Rank  Bear Rank Bear Perc  \
# 0        Bearish Reversal         NaN         37         44       50%
# 1    Bullish Continuation         NaN         50         40       54%
# ...

# %%
a=a.drop(['Unnamed: 0','Unnamed: 4','Unnamed: 9'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-04986dd50019> in <module>
# ----> 1 a=a.drop(['Unnamed: 0','Unnamed: 4','Unnamed: 9'], axis=1)
#
# NameError: name 'a' is not defined

# %%
a.sort_values(['Bull Rank', 'Freq'], ascending=True)
# Out:
#              Theoretical             Act Bull               Act Bear  \
# 17      Bullish Reversal  Bearish Continuation                  None
# 61  Bullish Continuation  Bullish Continuation  Bullish Continuation
# 88      Bullish Reversal      Bullish Reversal      Bullish Reversal
# 84  Bearish Continuation      Bullish Reversal      Bullish Reversal
# 89      Bullish Reversal      Bullish Reversal      Bullish Reversal
# ..                   ...                   ...                   ...
# 20      Bullish Reversal          Continuation          Continuation
# 1       Bearish Reversal      Bearish Reversal  Bullish Continuation
# 44                  None          Continuation              Reversal
# 23      Bearish Reversal      Bearish Reversal      Bearish Reversal
# 78                  None              Reversal              Reversal
#
#     Bull Rank  Bear Rank Bear Perc Bull Perc  Freq  OPT
# 17          0          0        N%       75%   103  101
# ...

# %%
z=a[(a["Theoretical"]==a["Act Bull "]) &(a["Theoretical"]==a["Act Bear"])] 
z
# Out:
#               Theoretical             Act Bull               Act Bear  \
# 5        Bullish Reversal      Bullish Reversal      Bullish Reversal
# 6        Bullish Reversal      Bullish Reversal      Bullish Reversal
# 8        Bearish Reversal      Bearish Reversal      Bearish Reversal
# 9        Bearish Reversal      Bearish Reversal      Bearish Reversal
# 10       Bullish Reversal      Bullish Reversal      Bullish Reversal
# 11       Bearish Reversal      Bearish Reversal      Bearish Reversal
# 12       Bullish Reversal      Bullish Reversal      Bullish Reversal
# 18       Bearish Reversal      Bearish Reversal      Bearish Reversal
# 23       Bearish Reversal      Bearish Reversal      Bearish Reversal
# 26       Bullish Reversal      Bullish Reversal      Bullish Reversal
# 32       Bearish Reversal      Bearish Reversal      Bearish Reversal
# 33       Bullish Reversal      Bullish Reversal      Bullish Reversal
# ...

# %%
zbur=z[z["Theoretical"]=="Bullish Reversal"].sort_values(["Bull Rank"], ascending = True)
zbuc=z[z["Theoretical"]=="Bullish Continuation"].sort_values(["Bull Rank"], ascending = True)
zber=z[z["Theoretical"]=="Bearish Reversal"].sort_values(["Bear Rank"], ascending = True)
zbec=z[z["Theoretical"]=="Bearish Continuation"].sort_values(["Bear Rank"], ascending = True)

# %%
zbur
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-78a6ac47f989> in <module>
# ----> 1 zbur
#
# NameError: name 'zbur' is not defined

# %%
b=a[(a['Bull Rank']<60) & (a["Freq"]<70) & (a["Act Bull "]=="Bullish Continuation" )].sort_values(['Bull Rank'], ascending=True)[:10]

# %%
b
# Out:
#               Theoretical             Act Bull               Act Bear  \
# 19       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 102  Bullish Continuation  Bullish Continuation  Bullish Continuation
# 27       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 52       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 7        Bearish Reversal  Bullish Continuation  Bullish Continuation
# 74       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 39       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 42       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 94       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 40       Bearish Reversal  Bullish Continuation      Bearish Reversal
#
#      Bull Rank  Bear Rank Bear Perc Bull Perc  Freq  OPT
# 19           4          4       75%       77%    48   93
# 102          4          7       72%       75%    20   42
# ...

# %%
| (a["Act Bull "]== "Bullish Reversal")

# %% [markdown]
# # A New Begginning

# %%
import pandas as pd

# %%
df=pd.read_csv("output.csv")
df
# Out:
#      Unnamed: 0           Theoretical             Act Bull   \
# 0             0      Bearish Reversal  Bullish Continuation
# 1             1      Bearish Reversal      Bearish Reversal
# 2             2      Bearish Reversal  Bullish Continuation
# 3             3      Bearish Reversal      Bearish Reversal
# 4             4      Bearish Reversal      Bearish Reversal
# ..          ...                   ...                   ...
# 98           98  Bullish Continuation      Bearish Reversal
# 99           99      Bearish Reversal  Bullish Continuation
# 100         100  Bullish Continuation  Bullish Continuation
# 101         101  Bearish Continuation  Bearish Continuation
# 102         102  Bullish Continuation  Bullish Continuation
#
#                  Act Bear  Unnamed: 4  Bull Rank  Bear Rank Bear Perc  \
# 0        Bearish Reversal         NaN         37         44       50%
# 1    Bullish Continuation         NaN         50         40       54%
# ...

# %%
df=df.drop(['Unnamed: 0','Unnamed: 4','Unnamed: 9'], axis=1)

# %%
df
# Out:
#               Theoretical             Act Bull               Act Bear  \
# 0        Bearish Reversal  Bullish Continuation      Bearish Reversal
# 1        Bearish Reversal      Bearish Reversal  Bullish Continuation
# 2        Bearish Reversal  Bullish Continuation  Bullish Continuation
# 3        Bearish Reversal      Bearish Reversal  Bullish Continuation
# 4        Bearish Reversal      Bearish Reversal  Bullish Continuation
# ..                    ...                   ...                   ...
# 98   Bullish Continuation      Bearish Reversal      Bearish Reversal
# 99       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 100  Bullish Continuation  Bullish Continuation  Bullish Continuation
# 101  Bearish Continuation  Bearish Continuation  Bearish Continuation
# 102  Bullish Continuation  Bullish Continuation  Bullish Continuation
#
#      Bull Rank  Bear Rank Bear Perc Bull Perc  Freq  OPT
# 0           37         44       50%       53%    52   90
# ...

# %%
Secured=df[(df["Theoretical"]==df["Act Bull "]) &(df["Theoretical"]==df["Act Bear"])] 
z=Secured
z
# Out:
#               Theoretical             Act Bull               Act Bear  \
# 5        Bullish Reversal      Bullish Reversal      Bullish Reversal
# 6        Bullish Reversal      Bullish Reversal      Bullish Reversal
# 8        Bearish Reversal      Bearish Reversal      Bearish Reversal
# 9        Bearish Reversal      Bearish Reversal      Bearish Reversal
# 10       Bullish Reversal      Bullish Reversal      Bullish Reversal
# 11       Bearish Reversal      Bearish Reversal      Bearish Reversal
# 12       Bullish Reversal      Bullish Reversal      Bullish Reversal
# 18       Bearish Reversal      Bearish Reversal      Bearish Reversal
# 23       Bearish Reversal      Bearish Reversal      Bearish Reversal
# 26       Bullish Reversal      Bullish Reversal      Bullish Reversal
# 32       Bearish Reversal      Bearish Reversal      Bearish Reversal
# 33       Bullish Reversal      Bullish Reversal      Bullish Reversal
# ...

# %%
zbur=z[z["Theoretical"]=="Bullish Reversal"].sort_values(["Freq"], ascending = True)
zbuc=z[z["Theoretical"]=="Bullish Continuation"].sort_values(["Freq"], ascending = True)
zber=z[z["Theoretical"]=="Bearish Reversal"].sort_values(["Freq"], ascending = True)
zbec=z[z["Theoretical"]=="Bearish Continuation"].sort_values(["Freq"], ascending = True)

# %% [markdown]
# ### All Four Secured

# %%
df
# Out:
#               Theoretical             Act Bull               Act Bear  \
# 0        Bearish Reversal  Bullish Continuation      Bearish Reversal
# 1        Bearish Reversal      Bearish Reversal  Bullish Continuation
# 2        Bearish Reversal  Bullish Continuation  Bullish Continuation
# 3        Bearish Reversal      Bearish Reversal  Bullish Continuation
# 4        Bearish Reversal      Bearish Reversal  Bullish Continuation
# ..                    ...                   ...                   ...
# 98   Bullish Continuation      Bearish Reversal      Bearish Reversal
# 99       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 100  Bullish Continuation  Bullish Continuation  Bullish Continuation
# 101  Bearish Continuation  Bearish Continuation  Bearish Continuation
# 102  Bullish Continuation  Bullish Continuation  Bullish Continuation
#
#      Bull Rank  Bear Rank Bear Perc Bull Perc  Freq  OPT
# 0           37         44       50%       53%    52   90
# ...

# %%
(zbur).to_csv("zbur.csv")
(zbuc).to_csv("zbuc.csv")
(zber).to_csv("zber.csv")
(zbec).to_csv("zbec.csv")

# %%
zbuc
# Out:
#               Theoretical             Act Bull               Act Bear  \
# 102  Bullish Continuation  Bullish Continuation  Bullish Continuation
# 76   Bullish Continuation  Bullish Continuation  Bullish Continuation
# 100  Bullish Continuation  Bullish Continuation  Bullish Continuation
# 72   Bullish Continuation  Bullish Continuation  Bullish Continuation
# 70   Bullish Continuation  Bullish Continuation  Bullish Continuation
# 61   Bullish Continuation  Bullish Continuation  Bullish Continuation
#
#      Bull Rank  Bear Rank Bear Perc Bull Perc  Freq  OPT
# 102          4          7       72%       75%    20   42
# 76          12         18       64%       66%    73   46
# 100         26         42       53%       57%    74    5
# 72           6         10       69%       72%    76   36
# 70           5          2       79%       74%    88   94
# 61           1         16       67%       78%    93   86

# %% [markdown]
# ### Four with Median=

# %%
print("Bull Median: ",zbur["Bull Rank"].median())
print("Freq Median: ",zbur["Freq"].median())
# Out:
# Bull Median:  19.0
# Freq Median:  38.0

# %%
burm=[zbur["Bull Rank"].median(),zbur["Freq"].median()]
bucm=[zbuc["Bull Rank"].median(),zbuc["Freq"].median()]
berm=[zber["Bear Rank"].median(),zber["Freq"].median()]
becm=[zbec["Bear Rank"].median(),zbec["Freq"].median()]

# %%
print(burm,bucm, berm,becm)

# %%
zbur[(zbur["Bull Rank"]<burm[0]) &( zbur["Freq"]<burm[1])]
# Out:
#          Theoretical         Act Bull           Act Bear  Bull Rank  \
# 10  Bullish Reversal  Bullish Reversal  Bullish Reversal         11
# 87  Bullish Reversal  Bullish Reversal  Bullish Reversal          9
# 80  Bullish Reversal  Bullish Reversal  Bullish Reversal         18
# 6   Bullish Reversal  Bullish Reversal  Bullish Reversal         17
#
#     Bear Rank Bear Perc Bull Perc  Freq  OPT
# 10         14       71%       71%    22   62
# 87          8       74%       75%    24   34
# 80         21       61%       66%    28   47
# 6          18       67%       66%    32   31

# %%
zbuc[(zbuc["Bull Rank"]<bucm[0]) &( zbuc["Freq"]<bucm[1])]
# Out:
#               Theoretical             Act Bull               Act Bear  \
# 102  Bullish Continuation  Bullish Continuation  Bullish Continuation
#
#      Bull Rank  Bear Rank Bear Perc Bull Perc  Freq  OPT
# 102          4          7       72%       75%    20   42

# %%
zbec[(zbec["Bull Rank"]<becm[0]) &( zbec["Freq"]<becm[1])]
# Out:
#               Theoretical             Act Bull               Act Bear  \
# 101  Bearish Continuation  Bearish Continuation  Bearish Continuation
# 95   Bearish Continuation  Bearish Continuation  Bearish Continuation
#
#      Bull Rank  Bear Rank Bear Perc Bull Perc  Freq  OPT
# 101         11          6       73%       67%    23    7
# 95          10          9       69%       68%    29   10

# %%
zber[(zber["Bull Rank"]<berm[0]) &( zber["Freq"]<berm[1])]
# Out:
#          Theoretical         Act Bull           Act Bear  Bull Rank  \
# 32  Bearish Reversal  Bearish Reversal  Bearish Reversal          5
# 9   Bearish Reversal  Bearish Reversal  Bearish Reversal         16
# 86  Bearish Reversal  Bearish Reversal  Bearish Reversal         15
#
#     Bear Rank Bear Perc Bull Perc  Freq  OPT
# 32          5       82%       79%    11   91
# 9          17       69%       68%    19   63
# 86         16       70%       69%    21   39

# %%
df1 = z.merge(df, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='right_only']
df1
# Out:
#               Theoretical             Act Bull               Act Bear  \
# 46       Bearish Reversal  Bullish Continuation      Bearish Reversal
# 47       Bearish Reversal      Bearish Reversal  Bullish Continuation
# 48       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 49       Bearish Reversal      Bearish Reversal  Bullish Continuation
# 50       Bearish Reversal      Bearish Reversal  Bullish Continuation
# 51       Bearish Reversal  Bullish Continuation  Bullish Continuation
# 52                   None              Reversal          Continuation
# 53                   None          Continuation          Continuation
# 54                   None          Continuation              Reversal
# 55                   None              Reversal          Continuation
# 56       Bullish Reversal  Bearish Continuation                  None
# 57       Bearish Reversal  Bullish Continuation  Bullish Continuation
# ...

# %%
Neg=df[(df["Theoretical"]=="None") | (df["Act Bear"]=="None")]

# %%
len(Neg)
# Out:
# 11
